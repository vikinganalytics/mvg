# %% [markdown]
# # Introduction
#
# The MultiViz Vibration Service is an analytics service based on the MultiViz Vibration Engine.
# To access it Viking Analytics provides a REST API towards its analytics server.
# To simplify the access of the Vibration service, Viking Analytics provides a Python Package
# called VPP, which allows to interact with the vibration service via regular python calls.
#
# This interactive document shall show the whole flow working with the vibration service from
# Python, from data upload to retrieval of analysis results.
#
# ## Signing up for the serivce
#
# For commercial use of the services you will need to acquire a token from Viking Analytics.
# For the example here, we can use a built in token for demo, we also use a special
# URL for demo cases.
#
# ## Python Pre-requisites
#
# 1. Make sure you have Python 3.6 or higher installed.
# 2. Install the VPP package from TBD
# 3. Make sure you have the following packages installed (json, matplotlib...)
#
# In the follwing section we will walk through the code needed for the API interaction

# %% [markdown]
# ### Setting up URL and Token
#
# For any call to the API, you will need to provide the server URL ('endpoint') and the
# token. To simplify this interaction the VPP library defines a class VPP, by means of
# which you can instantiate a session object chaching URL and token and providing methods
# for the API call.

# %%
import vpp.vpp_analysis_stub as vpp
session = vpp.VPP_analysis_stub("http://127.0.0.1:8000", "NO TOKEN")

# %% [markdown]
# The ´session´ object now caches the URL and token and is ready to interact
# with the analytics service

# %% [markdown]
# ### Checking if the service is alive
#
# To check if the service is alive, we will query for information about the API.

# %%
session.say_hello()
# Out:
# {'message': 'Vibium App!'}

# %% [markdown]
# If everything goes well, a dictionary with the proudct name and the API version shall be returned.

# %% [markdown]
# ### Creating a Source
#
# A source represents a vibration data source, typically a vibration sensor. Internally in the
# analytics engine and the anaytics data storage, all vibration data is stored under its source.
# A source basically is an ID, the source ID and meta data with a few required fields (TBD not yet)
# and the possibility to store arbitrary customer specific 'free form' data along the source. The vibration service
# will only rely on the required fields, the free form data is a possibility for the client side to
# keep together source information, measurements and meta data which may be interesting for
# the analytics features built by means of the service. Example could be location of sensor, the asset
# which it is mounted on etc.
# As we will see later, timestamps are internally represented as millisconds since EPOCH (Jan 1st 1970),
# for that reason it is good practice to include the timezone where the measurement originated in
# the meta data.

# %%
source_id = "my_first_source"
meta_information = {'location': 'Molnlycke', 'assed ID': 't-55', 'timezone': 'Europe/Stockholm'}
session.create_source(source_id,meta_information)

# %% [markdown]
# The call returns silently, unless the resource could not be successfully created. Just to show
# what happens in the latter case, lets pass a malformed call lacking the meta information.

# %%
session.create_source(source_id)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-acdc49f797a3> in <module>
# ----> 1 session.create_source(source_id)
#
# TypeError: create_source() missing 1 required positional argument: 'meta'

# %% [markdown]
# It is the caller's responsibility to handle error conditions. When something goes wrong expections will be raised,
# either by the type checking mechanism in the VPP library (as above) or by the analytics server. In the latter
# caseHTTP response status codes will be returned; a list can be found [here](https://developer.mozilla.org/sv-SE/docs/Web/HTTP/Status).
# So let's try to catch the above error:

# %%
try:
    session.create_source(source_id)
except:
    print("Something went wrong")
# Out:
# Something went wrong

# %% [markdown]
# ### List sources
# We can now check if our source actually has been created, by listing all the sources in the database.
# TBD: wrong response from server (fixed in Mohsen's PR)

# %%
sources = session.list_sources()
print(f"Retrieved a total of {len(sources)} sources")
# Out:
# Retrieved a total of 467 sources

# %%
sources
# Out:
# [{'source_id': 'u0001',
#   'timestamp': 1570186860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0001',
#   'timestamp': 1570273260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0001',
#   'timestamp': 1570359660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0001',
#   'timestamp': 
,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1571396460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1571482860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1571569260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1571655660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1571742060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1571828460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1571914860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1572001260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1572087660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1572177660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1572264060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1572350460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1572436860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1572523260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1573041660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1573128060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1573214460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1573300860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1573387260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1573473660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1573560060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1573646460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1573732860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1573819260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1573905660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1573992060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1574078460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1574164860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1574251260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1574337660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0007',
#   'timestamp': 1574424060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1570186860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1570273260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1570359660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1570446060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1570532460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1570618860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1570705260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1570791660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1570878060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1570964460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1571050860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1571137260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1571223660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1571310060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1571396460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1571482860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1571569260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1571655660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1571742060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1571828460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1571914860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1572001260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1572087660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1572177660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1572264060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1572350460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1572436860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1572523260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1572609660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1572696060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1572782460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1572868860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1572955260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1573041660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1573128060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0008',
#   'timestamp': 1573214460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1570186860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1570273260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1570359660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1570446060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1570532460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1570618860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1570705260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1570791660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1570878060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1570964460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1571050860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1571137260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1571223660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1571310060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1571396460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1571482860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1571569260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1571655660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1571742060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1571828460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1571914860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1572001260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1572087660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1572177660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1572264060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1572350460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1572436860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1572523260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1572609660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1572696060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1572782460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1572868860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1572955260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1573041660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1573128060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1573473660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1573560060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1573646460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1573732860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1573819260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1573905660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1573992060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1574078460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1574164860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1574251260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1574337660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0009',
#   'timestamp': 1574424060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1570186860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1570273260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1570359660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1570446060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1570532460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1570618860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1570705260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1570791660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1570878060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1570964460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1571050860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1571137260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1571223660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1571310060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1571396460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1571482860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1571828460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1571914860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1572001260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1572087660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1572177660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1572264060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1572350460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1572436860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1572523260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1572609660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1572696060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1572782460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1572868860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1572955260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1573041660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1573128060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1573214460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1573300860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1573387260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1573473660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1573560060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1573646460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1573732860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1573819260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1573905660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1573992060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1574078460,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1574164860,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1574251260,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1574337660,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}},
#  {'source_id': 'u0010',
#   'timestamp': 1574424060,
#   'duration': 40000,
#   'meta': {'sensor_type': 'mfpt'}}]

# %% [markdown]
# ## Upload measurements

# %% [markdown]
# Now that we have created a source, we can upload vibration measurements related to the source. To be processed by the analytics engine, the following requirements need to be met for the upload
#
# #### Meta-data:
#
# The meta data needs to contain the source id ('my_first_source' in our case), to associate the measurement to the source it orginated from, the timestamp when the measurement was recorded (as an integer representing the millisecongs since EPOCH), the duration (in seconds as float value), to do a correct conversion to the frequency domain. For later use on the client side, more meta information can be added, but it will not be processed by the analytics engine.
#
# #### Raw Data Values
#
# The raw data values shall be provided as list of floating point values. Raw data values need to represent a time-domain samples.
#
# #### Recommendations
#
# The anlytics engine is agnostic to the scale nature and scale of the Raw Data values. We recommend to use acceleration measured in g. But the algorithm will work equally well with other vibration like data as velocities or sound files in any arbitrary scale. The only imporant point is that the duration given in the meta data actually reflects the sampling time and that sampling rate under this period is constant. If this is not assured, the frequency conversion will have undefined results, and the output of the algorithm cannot be interpreted.
# Also it is required that a time series of measurements under one source use the sampe sampling rate.

# %% [markdown]
# ## Analysis

# %% [markdown]
# List features

# %% [markdown]
# Request (call) analysis

# %% [markdown]
# Get analysis

# %% [markdown]
# ## Display results

# %% [markdown]
# Plot mode changes

# %% [markdown]
# Read measurements and map them to modes

# %% [markdown]
# Display basic statistics on each mode

# %% [markdown]
# Results available:
# - Mode table
# - Labels table
# - output.json with experiment information
# - process_data (kpis & bands)
